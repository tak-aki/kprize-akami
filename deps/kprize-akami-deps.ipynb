# %%
# !pip download -d /kaggle/working vllm==0.7.1 bitsandbytes fsspec==2024.9.0 pre_commit==4.0.1 cfgv==3.4.0 dill==0.3.8 langchain_community
# !pip install /kaggle/working/*.whl --force-reinstall --root-user-action ignore --no-deps --no-index --find-links /kaggle/working
# !ls
# !rm -rf /kaggle/working/ray*
